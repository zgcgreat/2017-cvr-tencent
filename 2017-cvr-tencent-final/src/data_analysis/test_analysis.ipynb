# %%
import pandas as pd
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dtype = {'label':object, 'weekday':object, 'clickTime':object, 'creativeID':object, 'userID':object, 'positionID':object, 'connectionType':object,
       'telecomsOperator':object, 'age':object, 'gender':object, 'education':object, 'marriageStatus':object,
       'haveBaby':object, 'hometown':object, 'residence':object, 'sitesetID':object, 'positionType':object,
       'adID':object, 'camgaignID':object, 'advertiserID':object, 'appID':object, 'appPlatform':object,
       'appCategory':object}
test = pd.read_csv('../../data/test.csv', dtype=dtype)

# %%
len(test)
# Out:
# 338489

# %%
test.head()
# Out:
#   label clickTime creativeID   userID positionID connectionType  \
# 0    -1    310000       3745  1164848       3451              1
# 1    -1    310000       2284  2127247       1613              1
# 2    -1    310000       1456  2769125       5510              2
# 3    -1    310000       4565     9762       4113              2
# 4    -1    310000         49  2513636       3615              1
#
#   telecomsOperator age gender education     ...     hometown residence  \
# 0                3   5      2         1     ...          605       605
# 1                3   4      2         6     ...         2205      2301
# 2                1   5      1         0     ...            0      1502
# 3                3   4      1         3     ...         2405      2407
# 4                3   1      2         4     ...          307       307
#
#   sitesetID positionType  adID camgaignID advertiserID appID appPlatform  \
# 0         0            1  1166        430           80    14           2
# 1         0            1  1388        325           80    14           2
# 2         0            1  3379        411            3   465           1
# 3         0            1  3593        632            3   465           1
# 4         0            1  1469        535           80    14           2
#
#   appCategory
# 0           2
# 1           2
# 2         209
# 3         209
# 4           2
#
# [5 rows x 22 columns]

# %%
def time_transform(series):
    return str(series)[2:4]
test['clickTime'] = test['clickTime'].apply(time_transform)

# %%
test.describe(include=['object'])
# Out:
#          label clickTime creativeID   userID positionID connectionType  \
# count   338489    338489     338489   338489     338489         338489
# unique       1        24       2173   297466       4008              5
# top         -1        21       4565  2299240       2579              1
# freq    338489     24124      23138       16      41812         285998
#
#        telecomsOperator     age  gender education     ...     hometown  \
# count            338489  338489  338489    338489     ...       338489
# unique                4      17       3         8     ...          365
# top                   1       3       1         0     ...            0
# freq             181473   73446  154766     90400     ...       130230
#
#        residence sitesetID positionType    adID camgaignID advertiserID  \
# count     338489    338489       338489  338489     338489       338489
# unique       394         3            6    1236        323           52
# top            0         0            1    3593        632            3
# freq       29479    250551       205129   30534      30534       139522
#
#          appID appPlatform appCategory
# count   338489      338489      338489
# unique      32           2          10
# top        465           1         209
# freq    139522      283746      139522
#
# [4 rows x 22 columns]

# %%
def time_transform(series):
    return str(series)[2:4]
def convert_age(age):
    return int(int(age) / 5)
test['clickTime'] = test['clickTime'].apply(time_transform)
test['age'] = test['age'].apply(convert_age)
test['age'] = test['age'].astype('object')

# %%
test.drop('userID', axis=1, inplace=True)

# %%
# 画图查看分类变量的分布
categorical_feature = test.dtypes[test.dtypes == 'object'].index
for feature in categorical_feature:
    sns.countplot(x=test[feature], data=test)
    plt.show()
